# %% [markdown]
# ## 最新数据的处理
# > - 2025年8月31日steam_2025_5k-dataset-games_20250831.json
# > - 2025年9月1日
# steam_2025_5k-dataset-reviews_20250901.json
#
# ### 1. 处理背景
# 现有steam_.csv仅覆盖至 2019 年，时效性不足，计划下载 2025 年最新 Steam 数据集（如 Steam Games.csv），但新数据多为 JSON 格式（含游戏配置、免费状态等扩展字段），需转换为 CSV 以补充至原有数据集，丰富分析维度。
#
# ### 2. 数据预处理
# - json转csv
# - 初步保留有用特征并分类，删除冗余特征
# - 对保留特征逐个分析，进行差异化数据预处理（缺失值处理+异常值处理）

# %%
import json
import pandas as pd
import csv

# %%
games_json = json.load(open('raw_data/steam_2025_5k-dataset-games_20250831/steam_2025_5k-dataset-games_20250831.json'))
games = games_json['games']
games_json.keys()
# Out:
# dict_keys(['metadata', 'games'])

# %%
games = games_json['games']
len(games)
# Out:
# 8711

# %%
games[0]['app_details']['data'].keys()
# Out:
# dict_keys(['type', 'name', 'steam_appid', 'required_age', 'is_free', 'detailed_description', 'about_the_game', 'short_description', 'fullgame', 'header_image', 'capsule_image', 'capsule_imagev5', 'website', 'pc_requirements', 'mac_requirements', 'linux_requirements', 'developers', 'publishers', 'package_groups', 'platforms', 'categories', 'release_date', 'support_info', 'background', 'background_raw', 'content_descriptors', 'ratings'])

# %% [markdown]
# #### 2.1 steam_2025_5k-dataset-reviews数据集字段/特征提取
# - 读取评论数据，计算平均游玩时间

# %%
# 读取评论数据
review_json = json.load(open('raw_data/steam_2025_5k-dataset-reviews_20250901/steam_2025_5k-dataset-reviews_20250901.json', encoding='utf-8'))
reviews = review_json['reviews']

# 处理评论数据，计算平均游玩时间
game_reviews = {}
for review in reviews:
    appid = review['appid']
    game_reviews[appid] = review['review_data']['query_summary']
    sum_time = 0
    if review['review_data']['reviews']:
        for r in review['review_data']['reviews']:
            sum_time += r["author"]['playtime_forever']
        sum_time = sum_time / len(review['review_data']['reviews'])
    game_reviews[appid]['avg_playtime'] = sum_time

# %%
# --- 打印验证部分 ---
print(f"{'AppID':<10} | {'总评论数':<8} | {'好评率':<8} | {'平均游玩时间(分钟)':<12}")
print("-" * 60)

# 取前5个处理好的游戏进行展示
sample_appids = list(game_reviews.keys())[:5]

for appid in sample_appids:
    data = game_reviews[appid]
    
    total_reviews = data.get('total_reviews', 0)
    # 计算好评率 (如果评论数为0则为0)
    pos_reviews = data.get('total_positive', 0)
    pos_rate = f"{(pos_reviews / total_reviews * 100):.1f}%" if total_reviews > 0 else "0%"
    
    avg_time = data.get('avg_playtime', 0)
    
    print(f"{appid:<10} | {total_reviews:<10} | {pos_rate:<10} | {avg_time:<15.2f}")

print("-" * 60)
print(f"总计已处理游戏评论数: {len(game_reviews)}")
# Out:
# AppID      | 总评论数     | 好评率      | 平均游玩时间(分钟)
# ------------------------------------------------------------
# 2210       | 2777       | 87.4%      | 579.61
# 2726       | 0          | 0%         | 0.00
# 3220       | 93         | 50.5%      | 725.98
# 3340       | 111        | 81.1%      | 191.00
# 3372       | 0          | 0%         | 0.00
# ------------------------------------------------------------
# 总计已处理游戏评论数: 8711

# %% [markdown]
# - 后续数据清洗阶段，注意缺失值处理

# %% [markdown]
# #### 2.2 steam_2025_5k-dataset-games数据集字段/特征提取

# %%
# data的所有字段
fields = []
num = 0
for game in games:
    if 'data' in game['app_details']:
        fields.extend(game['app_details']['data'].keys())
fields = list(set(fields))
fields
needed_fields = ['metacritic', 'platforms', 'dlc', 'supported_languages',"achievements",
                 'publishers', 'controller_support', 'name', 'categories', 'developers',
                 'steam_appid', 'genres', 'reviews', 'type', 'required_age', 'price_overview',
                 'is_free', 'recommendations', 'ratings', 'release_date',]
# metacritic: 某网站评分 {"score": 80}
# dlc：统计数量代表游戏深度 [2314243,2314234]
# 'supported_languages'： "english,Chinese"
# "achievements": {"total": 24,}
# 'publishers': ["Rename Studio","Perla Oculta"]
# controller_support: 是否支持手柄
# #  "categories": [
#             {
#               "id": 2,
#               "description": "Single-player"
#             },
#             {
#               "id": 28,
#               "description": "Full controller support"
#             },
#             {
#               "id": 62,
#               "description": "Family Sharing"
#             }
#           ],
# "developers": [
# "Black Jacket Studios"
# ],
# "genres": [
# {
#     "id": "1",
#     "description": "Action"
# },
# {
#     "id": "29",
#     "description": "Massively Multiplayer"
# },
# {
#     "id": "37",
#     "description": "Free To Play"
# }
# ],
# "price_overview": {
# "currency": "USD",
# "initial": 899,
# "final": 899,
# "discount_percent": 0,
# "initial_formatted": "",
# "final_formatted": "$8.99"
# },
# "recommendations": {
# "total": 828
# },
# "achievements": {
# "total": 7,
# "highlighted": [
#     {
#     "name": "Complete all steganography puzzles.",
#     "path": "https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/746710/decac737d57264b09d18a764e4bf305a4e3297df.jpg"
#     },
# ]
# },
# "ratings": {
# "esrb": {
#     "rating": "t",
#     "descriptors": "Mild Fantasy Violence\r\nMild Lyrics\r\n\r\nMusic Downloads Not Rated by the ESRB"
# },
# "pegi": {
#     "rating": "12",
#     "descriptors": "Bad Language"
# },
# "bbfc": {
#     "rating": "12",
#     "descriptors": "Bad Language"
# },
# "usk": {
#     "rating": "6"
# },
# "oflc": {
#     "rating": "m",
#     "descriptors": "Infrequent sexual references"
# },
# "dejus": {
#     "descriptors": "Free"
# }
# }
# "release_date": {
# "coming_soon": true,
# "date": "To be announced"
# },

# %% [markdown]
# a. 按需手动提取与原有数据集匹配 / 扩展的字段
# - 基础字段：appid、name、required_age、is_free；
# - 扩展字段：游戏配置（PC requirement、Mac requirement）、supported_languages；
# - 冗余字段（如 website、域名、游戏宣传图片）暂不提取。
#
# b. 分为4大类：以下是各特征保留的**分析逻辑**（按分类整理）：
# - 基本信息
#     - `steam_appid`：游戏唯一标识 → 用于关联不同数据集的同一游戏，避免数据混淆（比如匹配旧数据集的游戏评价），是跨数据关联分析的基础。
#     - `name`：游戏名称 → 对应实际游戏产品，便于将分析结果落地到具体游戏案例（比如某款热门游戏的特征表现）。
#     - `type`：游戏类型（如正式游戏、Demo）→ 区分有效分析样本，Demo无完整数据，筛选出正式游戏才能做核心市场分析。
#     - `publishers`：发行商 → 分析发行商的游戏布局偏好（比如某发行商是否集中推某类题材），关联发行资源与游戏热度的关系。
#     - `developers`：开发商 → 挖掘开发商的创作风格（比如某开发商是否擅长动作类游戏），分析开发商能力与游戏口碑的关联。
#     - `release_date`：发布时间 → 追踪游戏行业的时间趋势（比如近年多人游戏的发布量变化），关联发布节点与市场竞争的关系（比如假期发布的游戏是否更易爆火）。
# - 游戏支持
#     - `platforms`：设备支持情况 → 设备覆盖范围决定潜在用户规模（仅支持PC的游戏触达用户少于多平台游戏），影响游戏的市场渗透能力。
#     - `supported_languages`：语言支持情况 → 语言种类越多，越能覆盖不同区域用户（比如支持中文的游戏可触达国内市场），直接关联区域销量差异。
#     - `controller_support`：手柄支持 → 适配手柄的游戏更契合主机/掌机用户的操作习惯，影响特定设备用户的选择意愿（比如主机用户更倾向选支持手柄的游戏）。
# - 类别
#     - `categories`：功能类别（如多人、单人）→ 功能类型决定游戏的社交属性/玩法定位（多人游戏对应社交需求用户），关联用户群体的需求偏好。
#     - `genres`：题材类型（如科幻、武侠）→ 题材对应特定兴趣圈层用户（科幻题材吸引科幻爱好者），分析不同题材的市场受欢迎程度。
# - 游戏深度
#     - `achievements`：成就系统 → 成就数量/难度反映游戏内容丰富度，成就越多的游戏更易吸引用户长期游玩，关联用户留存时长。
#     - `dlc`：扩展内容 → DLC数量反映游戏的长线运营能力，有持续DLC更新的游戏生命周期更长，关联游戏的长期营收潜力。
# - 评级
#     - `required_age`：年龄限制 → 年龄分级对应目标用户群体（18+游戏瞄准成年用户），影响用户的年龄层分布，关联不同年龄群体的消费偏好。
#     - `ratings`：官方评级 → 评级结果反映游戏内容合规性，高评级游戏可能无法在部分地区上架，关联游戏的区域发行范围。
# - 评价
#     - `metacritic`：媒体评分 → 专业评分反映游戏品质认可度，高分游戏更易获得初期口碑传播，关联游戏的初期销量增速。
#     - `reviews`：用户评论 → 用户真实反馈体现游戏的体验短板/亮点，负面评论多的游戏会影响后续用户购买决策。
#     - `recommendations`：用户推荐量 → 推荐量越高说明用户满意度越高，高推荐量游戏易形成自发传播，关联游戏的热度扩散速度。
# - 价格
#     - `price_overview`：价格详情 → 定价策略对应不同消费层级用户（低价游戏覆盖大众用户，高价游戏瞄准核心玩家），直接关联游戏的销量规模。
#     - `is_free`：免费标识 → 区分付费/免费商业模式，免费游戏靠内购盈利，付费游戏靠直接购买，关联不同模式下的用户规模与盈利效率差异。

# %% [markdown]
# #### 2.3 数据清洗（缺失值、异常值处理）
# 1. 游戏类别categories&generes：
# > steam_2025_5k-dataset-games_20250830.json
# - generes共32种，categories共79种
# - 痛点 - 一个游戏隶属多个分类（如某游戏同时属于 “Multi-player”“Online Multi-Player”“Valve Anti-Cheat enabled”）
# - 解决思路：
#     - 采用 Multi-Hot 编码转换：对每个游戏，生成与全局 categories 列表长度一致的 0/1 向量，若游戏属于某类别则对应位置标 1，否则标 0（如某游戏含 “Multi-player” 则向量中该类别位置为 1），既完整保留多分类信息，又转化为结构化数据，适配后续分析（如聚类、推荐系统中计算类别相似度），且操作直观简洁。
#
# > Multi-Hot：apple[0,0,1], orrange[0,1,0],banana[1,0,0]假如一篮子水果，有Apple又有Orange，就编码为[0,1,1]
#
# 2. 评论数据（reviews）：
# > steam_2025_5k-dataset-reviews_20250901.json
# - 痛点：
#     - ① 评论数据分散（原始reviews列表按单条评论存储，未按游戏聚合，无法直接关联单款游戏的整体评价）；
#     - ② 缺少用户游玩时长的统计维度（仅单用户playtime_forever，无游戏层面的平均游玩时间，难以反映用户粘性）；
#     - ③ 部分游戏无评论数据（game_reviews中无对应appid，易导致字段缺失）。
#
# - 解决思路：
#   1. 以`appid`为主关键字，构建`game_reviews`字典”的逻辑，将同一游戏的`query_summary`（含`total_reviews`总评论数、`total_positive`正面评论数、`total_negative`负面评论数、`review_score`评论分数等官方统计指标关联到对应游戏；
#   2. 处理评论数据缺失：对无评论的游戏标记为`None`，避免数据报错，商业模式识别阶段无需用到评论信息，后续再做处理。
#
#
# 3. 时间数据（release_date）：
# - 痛点：
#     - ① 发布日期格式不统一（原始格式有“Jul 16, 2025”，“15 Nov, 2025”还有乱码格式）；
#     - ② 游戏预售，存在“未发布”状态，无实际日期，属于无效分析样本）；
#     - ③ 部分日期为空值，且混杂测试版游戏（如名称含“playtest”“demo”“beta”的非正式游戏）。
# - 解决思路：
#   - 统一日期格式：适配多种原始格式，并由steamDB手动获取乱码日期（搜索游戏id即可差得），将日期转为“YYYY-MM-DD”标准格式；
#   - 标记未发布状态与处理空值：明确标记未发布游戏，对空日期标为`None`，避免“未发布数据干扰已发布游戏趋势分析”，符合会议中“排除无效数据”的原则；
#   - 过滤非正游戏时间样本：剔除测试版、演示版游戏（数量不多，影响不大），确保仅保留正式游戏的发布日期，避免非核心样本影响时间维度分析结果，呼应会议中“分析样本需为有效正式游戏”的要求。
#
#
# 4. 其他关键字段预处理（结合`needed_fields`与代码逻辑补充）：
# - 游戏支持相关（platforms/supported_languages）：
#   - 痛点 - `platforms`为嵌套字典（如`data['platforms']['windows']`）、`supported_languages`为长文本（含多语言逗号分隔，无法直接用于量化分析）。
#   - 解决思路：代码中拆解`platforms`为`platforms_windows`/`platforms_mac`/`platforms_linux`三个布尔字段（True/False反映是否支持），将`supported_languages`转为`support_english`（1=支持英语，0=不支持）的二值字段，既简化分析维度，又契合会议中“设备/语言支持需关联潜在用户规模”的分析逻辑。
#
# - 价格相关（price_overview/is_free）：
#   - 痛点 - `price_overview`为嵌套字典（含多种货币类型`currency`、多个价格），部分游戏无价格数据（除免费游戏外仍可能缺失）。
#   - 解决思路：
#     - 代码中拆解`price_overview`为`price_currency`/`price_initial`/`price_final`/`price_discount_percent`，对无价格数据的免费游戏填充`price_initial`/`price_final`为0（本身数量不多，且上steamDB查询后发现是下架游戏），确保价格字段结构化。
#     - 查看货币种类，发现种类不多，遂直接搜索2025.8.30的汇率转换统一为美元USD

# %%
# 游戏类别
categories = []
genres = []
for game in games:
    if 'data' in game['app_details']:
        data = game['app_details']['data']
        if data['type'] != 'game':
            continue
        if 'categories' in data:
            for category in data['categories']:
                if category['description'] not in categories:
                    categories.append(category['description'])
        if 'genres' in data:
            for genre in data['genres']:
                if genre['description'] not in genres:
                    genres.append(genre['description'])
print(len(categories))
print(len(genres))
# Out:
# 79
# 32

# %%
print(len(genres))
for g in genres:
    print(g)
# Out:
# 32
# Action
# RPG
# Indie
# Casual
# Adventure
# Strategy
# Free To Play
# Simulation
# Racing
# Sports
# Early Access
# Massively Multiplayer
# Utilities
# Animation & Modeling
# Game Development
# Software Training
# Design & Illustration
# Photo Editing
# Violent
# Gore
# Audio Production
# Video Production
# Education
# Экшены
# Инди
# Web Publishing
# Movie
# Sexual Content
# Nudity
# Acción
# Carreras
# Deportes

# %%
print(len(categories))
for c in categories:
    print(c)
# Out:
# 79
# Single-player
# Full controller support
# Family Sharing
# Steam Achievements
# Stats
# Steam Leaderboards
# Keyboard Only Option
# In-App Purchases
# Adjustable Text Size
# Custom Volume Controls
# Mouse Only Option
# Playable without Timed Input
# Save Anytime
# Steam Cloud
# Camera Comfort
# Color Alternatives
# Adjustable Difficulty
# Stereo Sound
# Partial Controller Support
# Multi-player
# PvP
# Shared/Split Screen PvP
# Co-op
# Shared/Split Screen Co-op
# Shared/Split Screen
# Remote Play Together
# Steam Trading Cards
# Online PvP
# Surround Sound
# Cross-Platform Multiplayer
# Online Co-op
# Captions available
# Tracked Controller Support
# VR Only
# Steam Workshop
# LAN Co-op
# VR Support
# Remote Play on TV
# VR Supported
# Includes level editor
# MMO
# Subtitle Options
# Touch Only Option
# Commentary available
# Valve Anti-Cheat enabled
# LAN PvP
# Includes Source SDK
# Remote Play on Phone
# Remote Play on Tablet
# HDR available
# Narrated Game Menus
# Steam Timeline
# Steam Turn Notifications
# Для одного игрока
# Достижения Steam
# Полная поддержка контроллеров
# Remote Play на телефоне
# Remote Play на планшете
# Remote Play на телевизоре
# Семейный доступ
# SteamVR Collectibles
# Un jugador
# Multijugador
# JcJ
# JcJ en línea
# JcJ en pantalla dividida/compartida
# Cooperativos
# Cooperativos en línea
# Cooperativos en pantalla dividida/compartida
# Pantalla dividida/compartida
# Multijugador multiplataforma
# Logros de Steam
# Tarjetas de Steam
# Compat. parcial con control
# Estadísticas
# Remote Play para móviles
# Remote Play para tabletas
# Remote Play para TV
# Préstamo familiar

# %%
review_json = json.load(open('raw_data/steam_2025_5k-dataset-reviews_20250901/steam_2025_5k-dataset-reviews_20250901.json', encoding='utf-8'))
review_json.keys()
# Out:
# dict_keys(['metadata', 'reviews'])

# %%
reviews = review_json['reviews']
len(reviews)
# Out:
# 8711

# %%
all_keys = []
for review in reviews:
    all_keys.extend(review['review_data']['query_summary'].keys())
print(list(set(all_keys)))
# Out:
# ['total_positive', 'review_score_desc', 'total_reviews', 'review_score', 'total_negative', 'num_reviews']

# %%
game_reviews = {}
for review in reviews:
    appid = review['appid']
    game_reviews[appid] = review['review_data']['query_summary']
    sum_time = 0
    for r in review['review_data']['reviews']:
        sum_time += r["author"]['playtime_forever']
    if sum_time != 0:
        sum_time = sum_time / len(review['review_data']['reviews'])
    game_reviews[appid]['avg_playtime'] = sum_time

game_reviews
# Out:
# {2210: {'num_reviews': 51,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 2428,
#   'total_negative': 349,
#   'total_reviews': 2777,
#   'avg_playtime': 579.6078431372549},
#  2726: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  3220: {'num_reviews': 93,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 47,
#   'total_negative': 46,
#   'total_reviews': 93,
#   'avg_playtime': 725.9784946236559},
#  3340: {'num_reviews': 1,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 90,
#   'total_negative': 21,
#   'total_reviews': 111,
#   'avg_playtime': 191.0},
#  3372: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  3800: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 319,
#   'total_negative': 79,
#   'total_reviews': 398,
#   'avg_playtime': 397.0},
#  4100: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 8,
#   'total_negative': 7,
#   'total_reviews': 15,
#   'avg_playtime': 57038.0},
#  4920: {'num_reviews': 11,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 7241,
#   'total_negative': 1249,
#   'total_reviews': 8490,
#   'avg_playtime': 10718.0},
#  5022: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5045: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5086: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5109: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5128: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5209: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5374: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5377: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5394: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5422: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5428: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5430: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5504: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5537: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5552: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5626: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5635: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5645: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5681: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5708: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5719: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5788: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5815: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5872: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  5883: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  6820: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  7910: {'num_reviews': 3,
#   'review_score': 0,
#   'review_score_desc': '3 user reviews',
#   'total_positive': 3,
#   'total_negative': 0,
#   'total_reviews': 3,
#   'avg_playtime': 6770.666666666667},
#  9200: {'num_reviews': 41,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 8986,
#   'total_negative': 2811,
#   'total_reviews': 11797,
#   'avg_playtime': 1246.9512195121952},
#  9880: {'num_reviews': 2,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 109,
#   'total_negative': 80,
#   'total_reviews': 189,
#   'avg_playtime': 116744.0},
#  10195: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 84,
#   'total_negative': 49,
#   'total_reviews': 133,
#   'avg_playtime': 0},
#  10420: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  10601: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  10609: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  10700: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  12850: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  15390: {'num_reviews': 15,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 1932,
#   'total_negative': 196,
#   'total_reviews': 2128,
#   'avg_playtime': 636.5333333333333},
#  18081: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  18110: {'num_reviews': 1,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 282,
#   'total_negative': 38,
#   'total_reviews': 320,
#   'avg_playtime': 494.0},
#  19940: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  21670: {'num_reviews': 8,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 986,
#   'total_negative': 322,
#   'total_reviews': 1308,
#   'avg_playtime': 483.875},
#  22893: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  23330: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  23410: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  24039: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  24096: {'num_reviews': 46,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 38,
#   'total_negative': 8,
#   'total_reviews': 46,
#   'avg_playtime': 0},
#  24098: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  24130: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  24938: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  25320: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  25330: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  25370: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  25380: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  25754: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  27900: {'num_reviews': 1,
#   'review_score': 4,
#   'review_score_desc': 'Mostly Negative',
#   'total_positive': 76,
#   'total_negative': 118,
#   'total_reviews': 194,
#   'avg_playtime': 538.0},
#  31229: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  32210: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  32330: {'num_reviews': 27,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 2324,
#   'total_negative': 365,
#   'total_reviews': 2689,
#   'avg_playtime': 1331.2962962962963},
#  32610: {'num_reviews': 6,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 115,
#   'total_negative': 100,
#   'total_reviews': 215,
#   'avg_playtime': 1218.5},
#  32650: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 129,
#   'total_negative': 37,
#   'total_reviews': 166,
#   'avg_playtime': 323.0},
#  32831: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  33910: {'num_reviews': 13,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 321,
#   'total_negative': 104,
#   'total_reviews': 425,
#   'avg_playtime': 1416.3076923076924},
#  34500: {'num_reviews': 32,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 27,
#   'total_negative': 5,
#   'total_reviews': 32,
#   'avg_playtime': 2622.40625},
#  34630: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 29,
#   'total_negative': 2,
#   'total_reviews': 31,
#   'avg_playtime': 1803.0},
#  34930: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  35088: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  35103: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  35140: {'num_reviews': 100,
#   'review_score': 9,
#   'review_score_desc': 'Overwhelmingly Positive',
#   'total_positive': 51829,
#   'total_negative': 2086,
#   'total_reviews': 53915,
#   'avg_playtime': 1298.58},
#  35417: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 33,
#   'total_negative': 7,
#   'total_reviews': 40,
#   'avg_playtime': 0},
#  37290: {'num_reviews': 15,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 14,
#   'total_negative': 1,
#   'total_reviews': 15,
#   'avg_playtime': 16032.0},
#  38150: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 56,
#   'total_negative': 8,
#   'total_reviews': 64,
#   'avg_playtime': 610.5},
#  39261: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  41520: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  41804: {'num_reviews': 3,
#   'review_score': 0,
#   'review_score_desc': '3 user reviews',
#   'total_positive': 3,
#   'total_negative': 0,
#   'total_reviews': 3,
#   'avg_playtime': 0},
#  42842: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  42847: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  45450: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 242,
#   'total_negative': 22,
#   'total_reviews': 264,
#   'avg_playtime': 1030.0},
#  46550: {'num_reviews': 3,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 187,
#   'total_negative': 140,
#   'total_reviews': 327,
#   'avg_playtime': 170.66666666666666},
#  47780: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 21424,
#   'total_negative': 1328,
#   'total_reviews': 22752,
#   'avg_playtime': 1110.32},
#  48228: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  48900: {'num_reviews': 48,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 41,
#   'total_negative': 7,
#   'total_reviews': 48,
#   'avg_playtime': 287.5416666666667},
#  50149: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  50233: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  50236: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  50238: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  50510: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 51,
#   'total_negative': 67,
#   'total_reviews': 118,
#   'avg_playtime': 51.0},
#  55223: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  56433: {'num_reviews': 5,
#   'review_score': 0,
#   'review_score_desc': '5 user reviews',
#   'total_positive': 5,
#   'total_negative': 0,
#   'total_reviews': 5,
#   'avg_playtime': 0},
#  56485: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '8 user reviews',
#   'total_positive': 8,
#   'total_negative': 0,
#   'total_reviews': 8,
#   'avg_playtime': 0},
#  56493: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 23,
#   'total_negative': 9,
#   'total_reviews': 32,
#   'avg_playtime': 0},
#  57010: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  57696: {'num_reviews': 26,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 21,
#   'total_negative': 5,
#   'total_reviews': 26,
#   'avg_playtime': 0},
#  61500: {'num_reviews': 11,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 670,
#   'total_negative': 184,
#   'total_reviews': 854,
#   'avg_playtime': 12419.363636363636},
#  63230: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  63399: {'num_reviews': 1,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 48,
#   'total_negative': 11,
#   'total_reviews': 59,
#   'avg_playtime': 0},
#  65740: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 392,
#   'total_negative': 373,
#   'total_reviews': 765,
#   'avg_playtime': 226.0},
#  65980: {'num_reviews': 34,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 8333,
#   'total_negative': 5419,
#   'total_reviews': 13752,
#   'avg_playtime': 19573.117647058825},
#  70605: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  70609: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  73170: {'num_reviews': 8,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 1502,
#   'total_negative': 158,
#   'total_reviews': 1660,
#   'avg_playtime': 72128.625},
#  80406: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80411: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80474: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80500: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80518: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80579: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80635: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80641: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80664: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80705: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80779: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80800: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80844: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80894: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80902: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80929: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80933: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80942: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80969: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80973: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80983: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80991: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  80993: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81011: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81021: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81035: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81036: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81050: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81097: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81128: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81229: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81241: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81287: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81337: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81343: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81344: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81348: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81384: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81409: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81436: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81438: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81448: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81454: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81462: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81474: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81475: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81552: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81558: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81574: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81633: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81721: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81744: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81810: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81826: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81832: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81841: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81879: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81886: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81929: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  81973: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82041: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82047: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82088: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82121: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82170: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  82177: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  90503: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 1,
#   'total_negative': 1,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  91345: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  91607: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 2,
#   'total_negative': 0,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  94000: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 276,
#   'total_negative': 223,
#   'total_reviews': 499,
#   'avg_playtime': 65.83},
#  94303: {'num_reviews': 23,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 21,
#   'total_negative': 2,
#   'total_reviews': 23,
#   'avg_playtime': 0},
#  95510: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  96000: {'num_reviews': 7,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 3238,
#   'total_negative': 434,
#   'total_reviews': 3672,
#   'avg_playtime': 384.2857142857143},
#  99850: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  102000: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  105300: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 208,
#   'total_negative': 78,
#   'total_reviews': 286,
#   'avg_playtime': 29.0},
#  105415: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  107410: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 198659,
#   'total_negative': 20499,
#   'total_reviews': 219158,
#   'avg_playtime': 30994.0},
#  107900: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  109600: {'num_reviews': 100,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 230,
#   'total_negative': 69,
#   'total_reviews': 299,
#   'avg_playtime': 13115.84},
#  113400: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 170,
#   'total_negative': 183,
#   'total_reviews': 353,
#   'avg_playtime': 32908.33},
#  113403: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  116100: {'num_reviews': 2,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 121,
#   'total_negative': 56,
#   'total_reviews': 177,
#   'avg_playtime': 151.0},
#  200174: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  200181: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  200733: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  201010: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 93,
#   'total_negative': 4,
#   'total_reviews': 97,
#   'avg_playtime': 3066.5},
#  201060: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  201290: {'num_reviews': 2,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 528,
#   'total_negative': 144,
#   'total_reviews': 672,
#   'avg_playtime': 132.5},
#  201790: {'num_reviews': 19,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 11780,
#   'total_negative': 944,
#   'total_reviews': 12724,
#   'avg_playtime': 1576.3157894736842},
#  201805: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 36,
#   'total_negative': 7,
#   'total_reviews': 43,
#   'avg_playtime': 0},
#  201890: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  202181: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 1,
#   'total_negative': 1,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  203777: {'num_reviews': 9,
#   'review_score': 0,
#   'review_score_desc': '9 user reviews',
#   'total_positive': 3,
#   'total_negative': 6,
#   'total_reviews': 9,
#   'avg_playtime': 0},
#  205830: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 167,
#   'total_negative': 5,
#   'total_reviews': 172,
#   'avg_playtime': 877.5},
#  205990: {'num_reviews': 3,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 665,
#   'total_negative': 303,
#   'total_reviews': 968,
#   'avg_playtime': 54819.0},
#  207210: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 853,
#   'total_negative': 525,
#   'total_reviews': 1378,
#   'avg_playtime': 1388.21},
#  208365: {'num_reviews': 31,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 23,
#   'total_negative': 8,
#   'total_reviews': 31,
#   'avg_playtime': 0},
#  208544: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 37,
#   'total_negative': 2,
#   'total_reviews': 39,
#   'avg_playtime': 0},
#  208793: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 53,
#   'total_negative': 33,
#   'total_reviews': 86,
#   'avg_playtime': 0},
#  209170: {'num_reviews': 13,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 852,
#   'total_negative': 113,
#   'total_reviews': 965,
#   'avg_playtime': 2430.3846153846152},
#  209370: {'num_reviews': 5,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 1581,
#   'total_negative': 95,
#   'total_reviews': 1676,
#   'avg_playtime': 438.4},
#  209817: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210034: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210055: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210063: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210071: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210080: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210130: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  210550: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 386,
#   'total_negative': 46,
#   'total_reviews': 432,
#   'avg_playtime': 204.0},
#  211500: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 1714,
#   'total_negative': 206,
#   'total_reviews': 1920,
#   'avg_playtime': 84285.0},
#  211994: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  212041: {'num_reviews': 16,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 16,
#   'total_negative': 0,
#   'total_reviews': 16,
#   'avg_playtime': 0},
#  212170: {'num_reviews': 3,
#   'review_score': 0,
#   'review_score_desc': '3 user reviews',
#   'total_positive': 3,
#   'total_negative': 0,
#   'total_reviews': 3,
#   'avg_playtime': 0},
#  213930: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 3,
#   'total_negative': 1,
#   'total_reviews': 4,
#   'avg_playtime': 0},
#  214050: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  215020: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  215100: {'num_reviews': 18,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 11,
#   'total_negative': 7,
#   'total_reviews': 18,
#   'avg_playtime': 1471.2222222222222},
#  215316: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  216210: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 116,
#   'total_negative': 47,
#   'total_reviews': 163,
#   'avg_playtime': 568.0},
#  216390: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 164,
#   'total_negative': 76,
#   'total_reviews': 240,
#   'avg_playtime': 4937.07},
#  216411: {'num_reviews': 25,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 18,
#   'total_negative': 7,
#   'total_reviews': 25,
#   'avg_playtime': 0},
#  216850: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  217470: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  217490: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  217570: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  217941: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 2,
#   'total_negative': 0,
#   'total_reviews': 2,
#   'avg_playtime': 7.0},
#  218290: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 70.0},
#  218620: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 393672,
#   'total_negative': 43006,
#   'total_reviews': 436678,
#   'avg_playtime': 14131.43},
#  218843: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 4,
#   'total_negative': 0,
#   'total_reviews': 4,
#   'avg_playtime': 0},
#  219102: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  220050: {'num_reviews': 100,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 292,
#   'total_negative': 326,
#   'total_reviews': 618,
#   'avg_playtime': 778.12},
#  220180: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  220440: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 17851,
#   'total_negative': 1238,
#   'total_reviews': 19089,
#   'avg_playtime': 1714.66},
#  221640: {'num_reviews': 32,
#   'review_score': 9,
#   'review_score_desc': 'Overwhelmingly Positive',
#   'total_positive': 17563,
#   'total_negative': 492,
#   'total_reviews': 18055,
#   'avg_playtime': 1150.375},
#  221980: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  222180: {'num_reviews': 18,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 9,
#   'total_negative': 9,
#   'total_reviews': 18,
#   'avg_playtime': 1005.7222222222222},
#  222587: {'num_reviews': 42,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 33,
#   'total_negative': 9,
#   'total_reviews': 42,
#   'avg_playtime': 0},
#  222621: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  222631: {'num_reviews': 27,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 12,
#   'total_negative': 15,
#   'total_reviews': 27,
#   'avg_playtime': 0},
#  222633: {'num_reviews': 16,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 12,
#   'total_negative': 4,
#   'total_reviews': 16,
#   'avg_playtime': 0},
#  223220: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 809,
#   'total_negative': 179,
#   'total_reviews': 988,
#   'avg_playtime': 751.0},
#  223330: {'num_reviews': 2,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 1370,
#   'total_negative': 530,
#   'total_reviews': 1900,
#   'avg_playtime': 14313.5},
#  223750: {'num_reviews': 4,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 584,
#   'total_negative': 98,
#   'total_reviews': 682,
#   'avg_playtime': 16654.5},
#  223770: {'num_reviews': 2,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 68,
#   'total_negative': 13,
#   'total_reviews': 81,
#   'avg_playtime': 0},
#  225430: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 2,
#   'total_negative': 0,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  226260: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  226490: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  226991: {'num_reviews': 8,
#   'review_score': 0,
#   'review_score_desc': '8 user reviews',
#   'total_positive': 7,
#   'total_negative': 1,
#   'total_reviews': 8,
#   'avg_playtime': 0},
#  226997: {'num_reviews': 7,
#   'review_score': 0,
#   'review_score_desc': '7 user reviews',
#   'total_positive': 6,
#   'total_negative': 1,
#   'total_reviews': 7,
#   'avg_playtime': 0},
#  228300: {'num_reviews': 38,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 8768,
#   'total_negative': 1756,
#   'total_reviews': 10524,
#   'avg_playtime': 818.7105263157895},
#  229810: {'num_reviews': 2,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 75,
#   'total_negative': 56,
#   'total_reviews': 131,
#   'avg_playtime': 49.5},
#  230070: {'num_reviews': 17,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 2773,
#   'total_negative': 605,
#   'total_reviews': 3378,
#   'avg_playtime': 2225.9411764705883},
#  230884: {'num_reviews': 7,
#   'review_score': 0,
#   'review_score_desc': '7 user reviews',
#   'total_positive': 6,
#   'total_negative': 1,
#   'total_reviews': 7,
#   'avg_playtime': 0},
#  231465: {'num_reviews': 11,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 8,
#   'total_negative': 3,
#   'total_reviews': 11,
#   'avg_playtime': 0},
#  231480: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 50,
#   'total_negative': 46,
# ...
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  509664: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 4,
#   'total_negative': 0,
#   'total_reviews': 4,
#   'avg_playtime': 0},
#  509712: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  509723: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  509725: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  509732: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  509920: {'num_reviews': 3,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 26,
#   'total_negative': 14,
#   'total_reviews': 40,
#   'avg_playtime': 86.0},
#  510690: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  510710: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 1,
#   'total_negative': 3,
#   'total_reviews': 4,
#   'avg_playtime': 326.5},
#  511010: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 21,
#   'total_negative': 16,
#   'total_reviews': 37,
#   'avg_playtime': 775.0},
#  511140: {'num_reviews': 1,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 220,
#   'total_negative': 18,
#   'total_reviews': 238,
#   'avg_playtime': 387.0},
#  512770: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 20,
#   'total_negative': 2,
#   'total_reviews': 22,
#   'avg_playtime': 31.0},
#  512900: {'num_reviews': 99,
#   'review_score': 9,
#   'review_score_desc': 'Overwhelmingly Positive',
#   'total_positive': 15976,
#   'total_negative': 619,
#   'total_reviews': 16595,
#   'avg_playtime': 2111.242424242424},
#  513031: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 38,
#   'total_negative': 19,
#   'total_reviews': 57,
#   'avg_playtime': 0},
#  513420: {'num_reviews': 1,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 24,
#   'total_negative': 18,
#   'total_reviews': 42,
#   'avg_playtime': 24.0},
#  513610: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 32,
#   'total_negative': 5,
#   'total_reviews': 37,
#   'avg_playtime': 88.0},
#  513910: {'num_reviews': 20,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 19,
#   'total_negative': 1,
#   'total_reviews': 20,
#   'avg_playtime': 680.9},
#  514220: {'num_reviews': 3,
#   'review_score': 0,
#   'review_score_desc': '3 user reviews',
#   'total_positive': 3,
#   'total_negative': 0,
#   'total_reviews': 3,
#   'avg_playtime': 525.0},
#  514670: {'num_reviews': 75,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 47,
#   'total_negative': 28,
#   'total_reviews': 75,
#   'avg_playtime': 561.2133333333334},
#  515000: {'num_reviews': 14,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 12,
#   'total_negative': 2,
#   'total_reviews': 14,
#   'avg_playtime': 452.7142857142857},
#  515050: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  515060: {'num_reviews': 5,
#   'review_score': 0,
#   'review_score_desc': '5 user reviews',
#   'total_positive': 4,
#   'total_negative': 1,
#   'total_reviews': 5,
#   'avg_playtime': 267.0},
#  515240: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '5 user reviews',
#   'total_positive': 4,
#   'total_negative': 1,
#   'total_reviews': 5,
#   'avg_playtime': 0},
#  516110: {'num_reviews': 3,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 629,
#   'total_negative': 72,
#   'total_reviews': 701,
#   'avg_playtime': 749.3333333333334},
#  516860: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  517130: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 477,
#   'total_negative': 69,
#   'total_reviews': 546,
#   'avg_playtime': 2807.11},
#  517910: {'num_reviews': 25,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 23,
#   'total_negative': 2,
#   'total_reviews': 25,
#   'avg_playtime': 52.48},
#  518650: {'num_reviews': 1,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 54,
#   'total_negative': 5,
#   'total_reviews': 59,
#   'avg_playtime': 47.0},
#  518760: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  518842: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  518954: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  518977: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  520430: {'num_reviews': 12,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 6,
#   'total_negative': 6,
#   'total_reviews': 12,
#   'avg_playtime': 0},
#  520761: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  521110: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 171.0},
#  521980: {'num_reviews': 3,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 89,
#   'total_negative': 85,
#   'total_reviews': 174,
#   'avg_playtime': 72.66666666666667},
#  522090: {'num_reviews': 1,
#   'review_score': 4,
#   'review_score_desc': 'Mostly Negative',
#   'total_positive': 41,
#   'total_negative': 73,
#   'total_reviews': 114,
#   'avg_playtime': 25.0},
#  522862: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  522980: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  523070: {'num_reviews': 1,
#   'review_score': 4,
#   'review_score_desc': 'Mostly Negative',
#   'total_positive': 7,
#   'total_negative': 16,
#   'total_reviews': 23,
#   'avg_playtime': 86.0},
#  523484: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  523750: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  524240: {'num_reviews': 5,
#   'review_score': 0,
#   'review_score_desc': '5 user reviews',
#   'total_positive': 3,
#   'total_negative': 2,
#   'total_reviews': 5,
#   'avg_playtime': 104.6},
#  525100: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 0,
#   'total_negative': 1,
#   'total_reviews': 1,
#   'avg_playtime': 12.0},
#  525190: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 67,
#   'total_negative': 20,
#   'total_reviews': 87,
#   'avg_playtime': 332.0},
#  525281: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 2,
#   'total_negative': 2,
#   'total_reviews': 4,
#   'avg_playtime': 0},
#  525350: {'num_reviews': 20,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 8,
#   'total_negative': 12,
#   'total_reviews': 20,
#   'avg_playtime': 74.25},
#  525480: {'num_reviews': 14,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 2854,
#   'total_negative': 408,
#   'total_reviews': 3262,
#   'avg_playtime': 2873.785714285714},
#  525820: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  525821: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  525822: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  525930: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  526204: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  526470: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  526760: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  527250: {'num_reviews': 9,
#   'review_score': 0,
#   'review_score_desc': '9 user reviews',
#   'total_positive': 7,
#   'total_negative': 2,
#   'total_reviews': 9,
#   'avg_playtime': 468.22222222222223},
#  527560: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  528790: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 0,
#   'total_negative': 1,
#   'total_reviews': 1,
#   'avg_playtime': 9.0},
#  529720: {'num_reviews': 8,
#   'review_score': 0,
#   'review_score_desc': '8 user reviews',
#   'total_positive': 5,
#   'total_negative': 3,
#   'total_reviews': 8,
#   'avg_playtime': 49.5},
#  530180: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 2,
#   'total_negative': 0,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  530540: {'num_reviews': 100,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 72,
#   'total_negative': 29,
#   'total_reviews': 101,
#   'avg_playtime': 341.04},
#  530711: {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 3061,
#   'total_negative': 302,
#   'total_reviews': 3363,
#   'avg_playtime': 0},
#  530760: {'num_reviews': 4,
#   'review_score': 5,
#   'review_score_desc': 'Mixed',
#   'total_positive': 723,
#   'total_negative': 892,
#   'total_reviews': 1615,
#   'avg_playtime': 0},
#  530860: {'num_reviews': 1,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 32,
#   'total_negative': 13,
#   'total_reviews': 45,
#   'avg_playtime': 225.0},
#  531100: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  531110: {'num_reviews': 21,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 18,
#   'total_negative': 3,
#   'total_reviews': 21,
#   'avg_playtime': 2693.5238095238096},
#  531210: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  531601: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 1,
#   'total_negative': 1,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  532000: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 0,
#   'total_negative': 1,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  533050: {'num_reviews': 1,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 25,
#   'total_negative': 5,
#   'total_reviews': 30,
#   'avg_playtime': 98.0},
#  533090: {'num_reviews': 9,
#   'review_score': 0,
#   'review_score_desc': '9 user reviews',
#   'total_positive': 7,
#   'total_negative': 2,
#   'total_reviews': 9,
#   'avg_playtime': 883.6666666666666},
#  533400: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  533402: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  533920: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 1,
#   'total_negative': 3,
#   'total_reviews': 4,
#   'avg_playtime': 20.5},
#  534380: {'num_reviews': 100,
#   'review_score': 6,
#   'review_score_desc': 'Mostly Positive',
#   'total_positive': 119460,
#   'total_negative': 30966,
#   'total_reviews': 150426,
#   'avg_playtime': 5077.39},
#  534640: {'num_reviews': 4,
#   'review_score': 0,
#   'review_score_desc': '4 user reviews',
#   'total_positive': 2,
#   'total_negative': 2,
#   'total_reviews': 4,
#   'avg_playtime': 0},
#  534720: {'num_reviews': 46,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 42,
#   'total_negative': 4,
#   'total_reviews': 46,
#   'avg_playtime': 78.84782608695652},
#  535042: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  535090: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  535102: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  535540: {'num_reviews': 1,
#   'review_score': 0,
#   'review_score_desc': '1 user reviews',
#   'total_positive': 1,
#   'total_negative': 0,
#   'total_reviews': 1,
#   'avg_playtime': 0},
#  536094: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  536100: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  536132: {'num_reviews': 0,
#   'review_score': 0,
#   'review_score_desc': 'No user reviews',
#   'total_positive': 0,
#   'total_negative': 0,
#   'total_reviews': 0,
#   'avg_playtime': 0},
#  537321: {'num_reviews': 2,
#   'review_score': 0,
#   'review_score_desc': '2 user reviews',
#   'total_positive': 2,
#   'total_negative': 0,
#   'total_reviews': 2,
#   'avg_playtime': 0},
#  538040: {'num_reviews': 3,
#   'review_score': 0,
#   'review_score_desc': '3 user reviews',
#   'total_positive': 3,
#   'total_negative': 0,
#   'total_reviews': 3,
#   'avg_playtime': 584.0},
#  538070: {'num_reviews': 7,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 1740,
#   'total_negative': 157,
#   'total_reviews': 1897,
#   'avg_playtime': 371.2857142857143},
#  ...}

# %%
# 统计样本中货币种类和数量
df = pd.read_csv('steam_games.csv')  # Read the CSV file into a DataFrame
price_currency = df['price_currency']  # Extract the 'price_currency' column
price_currency.value_counts()  # Count the occurrences of each currency
# Out:
# price_currency
# USD    2968
# EUR       9
# PHP       4
# AUD       4
# CAD       2
# RUB       2
# MXN       1
# PLN       1
# Name: count, dtype: int64

# %%
needed_fields = [
    # 基本信息
    'steam_appid',
    'name',
    'type',
    'publishers',
    'developers',
    'release_date',
    #支持
    'platforms',
    'supported_languages',
    'controller_support',
    #类别
    'categories',
    'genres',
    #游戏深度
    "achievements",
    'dlc',
    # 评级
    'required_age',
    'ratings',
    # 评价
    'metacritic',
    'reviews',
    'recommendations',
    # 价格
    'price_overview',
    'is_free',
    
]
import datetime

# 处理每一项，提取你想要的字段
rows = []
for game in games:
    if 'data' not in game['app_details']:
        continue
    data = game['app_details']['data']
    if data['type'] != 'game':
        continue
    if 'playtest' in game['name_from_applist'].lower() or 'demo' in game['name_from_applist'].lower() or 'beta' in game['name_from_applist'].lower():
        continue
    # print(data['release_date'], data['steam_appid'])
    row = {
        # 基本信息
        'steam_appid': data['steam_appid'],
        'name': game['name_from_applist'],
        'type': data['type'],
        # 'developers': ', '.join(d.get('developers', [])) if d.get('developers') else '',
        # 'publishers': ', '.join(d.get('publishers', [])) if d.get('publishers') else '',
        'developers': ';'.join(data['developers']) if 'developers' in data else None,
        'publishers': ';'.join(data['publishers']) if 'publishers' in data else None,
        # date 格式"Jul 16, 2025" 转为2025-07-16
        'release_date': 'Coming Soon' if data['release_date']['coming_soon'] is True
                        else (pd.to_datetime(data['release_date']['date'], format='mixed').strftime('%Y-%m-%d')) if  data['release_date']['date'] != '' else None,
        #支持
        'platforms_windows': data['platforms']['windows'],
        'platforms_mac': data['platforms']['mac'],
        'platforms_linux': data['platforms']['linux'],
        'support_english': (1 if 'english' in data['supported_languages'].lower() else 0) if 'supported_languages' in data else None,
        'supported_languages': data['supported_languages'] if 'supported_languages' in data else None,
        'controller_support': data['controller_support'] if 'controller_support' in data else None,
        #类别
        'categories': ';'.join([c['description'] for c in data['categories']]) if 'categories' in data else None,
        'genres': ';'.join([g['description'] for g in data['genres']]) if 'genres' in data else None,
        #游戏深度
        "achievements": data['achievements']['total'] if 'achievements' in data else None,
        'dlc': len(data['dlc']) if 'dlc' in data else None,
        # 评级
        'required_age': data['required_age'],
        'ratings': data['ratings'],
        # 评价
        'metacritic': data['metacritic'] if 'metacritic' in data else None,
        'reviews': data['reviews'] if 'reviews' in data else None,
        'recommendations': data['recommendations']['total'] if 'recommendations' in data else None,
        'total_reviews': game_reviews[data['steam_appid']]['total_reviews'] if data['steam_appid'] in game_reviews else None,
        'total_positive_reviews': game_reviews[data['steam_appid']]['total_positive'] if data['steam_appid'] in game_reviews else None,
        'total_negative_reviews': game_reviews[data['steam_appid']]['total_negative'] if data['steam_appid'] in game_reviews else None,
        'review_score': game_reviews[data['steam_appid']]['review_score'] if data['steam_appid'] in game_reviews else None,
        'review_score_desc': game_reviews[data['steam_appid']]['review_score_desc'] if data['steam_appid'] in game_reviews else None,
        'avg_playtime': game_reviews[data['steam_appid']]['avg_playtime'] if data['steam_appid'] in game_reviews else None, 
        
        # 价格
        'is_free': data['is_free'] if 'is_free' in data else None,
        'price_currency': data['price_overview']['currency'] if 'price_overview' in data else None,
        'price_initial': data['price_overview']['initial'] if 'price_overview' in data else 0,
        'price_final': data['price_overview']['final'] if 'price_overview' in data else 0,
        'price_discount_percent': data['price_overview']['discount_percent'] if 'price_overview' in data else 0,
    }
    rows.append(row)

# 写入csv文件
with open('steam_games.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=rows[0].keys())
    writer.writeheader()
    for row in rows:
        writer.writerow(row)
